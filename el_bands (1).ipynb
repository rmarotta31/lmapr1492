# %%
import numpy as np
import matplotlib.pyplot as plt
from mp_api.client import MPRester
from pymatgen.core.operations import SymmOp
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.electronic_structure import plotter
from pymatgen.electronic_structure.plotter import BSPlotter
from pymatgen.phonon.plotter import PhononBSPlotter
from jupyter_jsmol.pymatgen import quick_view
from lmapr1492 import plot_brillouin_zone, get_plot_bs, get_plot_dos, get_plot_bs_and_dos, get_branch_wavevectors
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
mp_key = "kMkuaNd0F7org0EE2QryQaonTKfVvGw4"
mp_id = "mp-30847"

# %%
with MPRester(mp_key) as m:
    prim_struc = m.get_structure_by_material_id(mp_id)
    el_bs = m.get_bandstructure_by_material_id(mp_id)
    el_dos = m.get_dos_by_material_id(mp_id)
    ph_bs = m.get_phonon_bandstructure_by_material_id(mp_id)
    ph_dos = m.get_phonon_dos_by_material_id(mp_id)
conv_struc = SpacegroupAnalyzer(prim_struc).get_conventional_standard_structure()
symmops = SpacegroupAnalyzer(conv_struc).get_space_group_operations()
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ElectronicStructureDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# MPRestError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 with MPRester(mp_key) as m:
#       2     prim_struc = m.get_structure_by_material_id(mp_id)
# ----> 3     el_bs = m.get_bandstructure_by_material_id(mp_id)
#       4     el_dos = m.get_dos_by_material_id(mp_id)
#       5     ph_bs = m.get_phonon_bandstructure_by_material_id(mp_id)
#
# File /usr/local/lib/python3.9/site-packages/mp_api/client/mprester.py:1229, in MPRester.get_bandstructure_by_material_id(self, material_id, path_type, line_mode)
#    1213 def get_bandstructure_by_material_id(
#    1214     self,
#    1215     material_id: str,
#    1216     path_type: BSPathType = BSPathType.setyawan_curtarolo,
#    1217     line_mode=True,
#    1218 ):
#    1219     """Get the band structure pymatgen object associated with a Materials Project ID.
#    1220
#    1221     Arguments:
#    (...)
#    1227         bandstructure (Union[BandStructure, BandStructureSymmLine]): BandStructure or BandStructureSymmLine object
#    1228     """
# -> 1229     return self.electronic_structure_bandstructure.get_bandstructure_from_material_id(  # type: ignore
#    1230         material_id=material_id, path_type=path_type, line_mode=line_mode
#    1231     )
#
# File /usr/local/lib/python3.9/site-packages/mp_api/client/routes/materials/electronic_structure.py:278, in BandStructureRester.get_bandstructure_from_material_id(self, material_id, path_type, line_mode)
#     271 bs_data = (
#     272     bs_doc[0].bandstructure  # type: ignore
#     273     if self.use_document_model
#     274     else bs_doc[0]["bandstructure"]  # type: ignore
#     275 )
#     277 if bs_data is None:
# --> 278     raise MPRestError(
#     279         f"No {path_type.value} band structure data found for {material_id}"
#     280     )
#     281 else:
#     282     bs_data: dict = (
#     283         bs_data.model_dump() if self.use_document_model else bs_data  # type: ignore
#     284     )
#
# MPRestError: No setyawan_curtarolo band structure data found for mp-30847

# %% [markdown]
# ![El%20bands.png](attachment:El%20bands.png)
